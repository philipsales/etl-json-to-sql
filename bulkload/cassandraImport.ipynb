# %%
import sys
from os import path
from os import walk
import re
import pandas as pd
import json
import logging
import subprocess

# %%
#logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

#logging.basicConfig
fh = logging.FileHandler('logs_cassandra_dump.txt')
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)
logger.addHandler(fh)

'''
#For streaming only
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
ch.setFormatter(formatter)
logger.addHandler(ch)
'''

logger.info('This is a test log message.')

# %%
class FileIterator:

    def __init__(self, input_root, input_folders, max_item):
        self.input_data_dir = input_root
        self.input_folders = input_folders
        self.max_item = max_item
        
    def iterate_filenames(self):
        resources = self.__iterate_dirfiles()
        files = self.__iterate_file(resources)
        return files
        
    def __iterate_dirfiles(self):
        path_files = []
        file_names = self.input_folders

        for file in file_names:
            path_files.append(input_data_dir + '/' + file)
        return path_files
    
    def __iterate_file(self, path_dbs):
        path_db_workload_files = []     
        for path_db in path_dbs:
            for root, dirs, files in walk(path_db):
                index = 0
                for filename in files:
                    
                    print('remaining files: ', len(files)-index)
                    
                    if index < self.max_item:
                        
                        if not filename.endswith(('.json~', '.swp', '-checkpoint.json')):
                            print('valid file: ',filename)
                            path_db_workload_files.append(root + '/' + filename)
                            index+=1
                            
                        if ''.join(dirs) != '.ipynb_checkpoints':
                            pass
                    else:
                        break

        
        return path_db_workload_files

# %%
class ContentReaderJSON():
    
    def __init__(self, filename_paths):
        self.filename_paths = filename_paths
        
    def get_data(self):
        data = []
        for filename_path in self.filename_paths:
            
            json = ReadJSON()
            #data.append(json.read(filename_path))

        return data

# %%
class ContentReader():
    
    def __init__(self, filename_paths):
        self.filename_paths = filename_paths
        
    def get_data(self):
        data = []
        tmp = ''
        index = 0
        
        for filename_path in self.filename_paths:
            
            read_json = ReadJSON()
            data = read_json.read(filename_path)
            database = 'ycsb'
            table = 'patient'
            
            print('remaining files: ', len(self.filename_paths)-index)
            
            try:
                cmd = '''cqlsh localhost 9042 -e 'INSERT INTO %s.%s JSON '"'"'%s'"'"';' ''' % (database, table, json.dumps(data))
                result = subprocess.run(cmd, shell=True, stdout=subprocess.PIPE, stdin=subprocess.PIPE, stderr=subprocess.PIPE)
                if result.returncode != 0:
                    print("error item:  ", data['id'])
                    print("error code: ", result.stderr)
                    print(cmd)
                else:
                    print("inserting:  ", data['id'])
                    result.stdout
                    index += 1
                   
            except Exception as e:
                print(e)
                result = e
        return result
            #data.append(json.read(filename_path))

        return data

# %%
class ReadJSON():
    
    @staticmethod
    def read(file_path):
        with open(file_path) as f:
            d = json.load(f)
        return d

# %%
class CassandraImport():
    
    @staticmethod
    def insert_all(data):
        database = 'ycsb'

        index = 0

        for item in data:
            
            print('remaining files: ', len(data)-index)
            
            try:

                cmd = '''cqlsh localhost 9042 -e 'INSERT INTO ycsb.patient JSON '"'"'%s'"'"';' ''' % json.dumps(item)
                result = subprocess.run(cmd, shell=True, stdout=subprocess.PIPE, stdin=subprocess.PIPE, stderr=subprocess.PIPE)
                if result.returncode != 0:
                    print("error item:  ", item['id'])
                    print("error code: ", result.stderr)
                    print(cmd)
                else:
                    print("inserting:  ", item['id'])
                    result.stdout
                    index += 1
                   
            except Exception as e:
                print(e)
                result = e
        return result

# %%
root_dir = '../'

input_data_folders = ['Patient']
input_data_dir = root_dir + 'output/fhir-json-cassandra/100'
max_count = 100

files = FileIterator(input_data_dir, input_data_folders, max_count)
input_dirpaths = files.iterate_filenames()

data = []
files = ContentReader(input_dirpaths)
data = files.get_data()

#result = CassandraImport.insert_all(data)
# Out:
# remaining files:  100
# valid file:  00525954.Patient.json
# remaining files:  99
# valid file:  019fe101.Patient.json
# remaining files:  98
# valid file:  039933a0.Patient.json
# remaining files:  97
# valid file:  03c2e1b5.Patient.json
# remaining files:  96
# valid file:  0debf275.Patient.json
# remaining files:  95
# valid file:  0ee8938d.Patient.json
# remaining files:  94
# valid file:  0fbd8ed9.Patient.json
# remaining files:  93
# valid file:  103f95eb.Patient.json
# remaining files:  92
# valid file:  13d0b13d.Patient.json
# remaining files:  91
# valid file:  13f9b410.Patient.json
# remaining files:  90
# valid file:  150ec7a2.Patient.json
# remaining files:  89
# valid file:  163950fe.Patient.json
# remaining files:  88
# valid file:  1a0b9aff.Patient.json
# remaining files:  87
# valid file:  1c18689e.Patient.json
# remaining files:  86
# valid file:  21e57853.Patient.json
# remaining files:  85
# valid file:  2295fbd8.Patient.json
# remaining files:  84
# valid file:  2805041e.Patient.json
# remaining files:  83
# valid file:  2a868ded.Patient.json
# remaining files:  82
# valid file:  2dc078cd.Patient.json
# remaining files:  81
# valid file:  2f5a5107.Patient.json
# remaining files:  80
# valid file:  30803573.Patient.json
# remaining files:  79
# valid file:  3b7ebb7e.Patient.json
# remaining files:  78
# valid file:  3c9a0fe6.Patient.json
# remaining files:  77
# valid file:  3c9ff6d5.Patient.json
# remaining files:  76
# valid file:  3f363411.Patient.json
# remaining files:  75
# valid file:  3f403543.Patient.json
# remaining files:  74
# valid file:  3f6ca148.Patient.json
# remaining files:  73
# valid file:  43fc2d9d.Patient.json
# remaining files:  72
# valid file:  4506837b.Patient.json
# remaining files:  71
# valid file:  4b8f21f6.Patient.json
# remaining files:  70
# valid file:  4c22cd07.Patient.json
# remaining files:  69
# valid file:  4e13f416.Patient.json
# remaining files:  68
# valid file:  5077322e.Patient.json
# remaining files:  67
# valid file:  517c31b6.Patient.json
# remaining files:  66
# valid file:  54296ed1.Patient.json
# remaining files:  65
# valid file:  56f18382.Patient.json
# remaining files:  64
# valid file:  59667014.Patient.json
# remaining files:  63
# valid file:  5cf627cb.Patient.json
# remaining files:  62
# valid file:  60e8789a.Patient.json
# remaining files:  61
# valid file:  61c0f781.Patient.json
# remaining files:  60
# valid file:  63db01d9.Patient.json
# remaining files:  59
# valid file:  653711aa.Patient.json
# remaining files:  58
# valid file:  67cbee98.Patient.json
# remaining files:  57
# valid file:  688c0771.Patient.json
# remaining files:  56
# valid file:  6a370e45.Patient.json
# remaining files:  55
# valid file:  6d615362.Patient.json
# remaining files:  54
# valid file:  6f8f470e.Patient.json
# remaining files:  53
# valid file:  70fcb282.Patient.json
# remaining files:  52
# valid file:  7288e90e.Patient.json
# remaining files:  51
# valid file:  770596b9.Patient.json
# remaining files:  50
# valid file:  79a1687e.Patient.json
# remaining files:  49
# valid file:  83b3beed.Patient.json
# remaining files:  48
# valid file:  862e0d5a.Patient.json
# remaining files:  47
# valid file:  887b7be5.Patient.json
# remaining files:  46
# valid file:  888c2d5f.Patient.json
# remaining files:  45
# valid file:  88a3d349.Patient.json
# remaining files:  44
# valid file:  8934b7cf.Patient.json
# remaining files:  43
# valid file:  895cd302.Patient.json
# remaining files:  42
# valid file:  8a34821b.Patient.json
# remaining files:  41
# valid file:  8a9356db.Patient.json
# remaining files:  40
# valid file:  8ada3b39.Patient.json
# remaining files:  39
# valid file:  8dbb72ab.Patient.json
# remaining files:  38
# valid file:  93f70310.Patient.json
# remaining files:  37
# valid file:  93fa40da.Patient.json
# remaining files:  36
# valid file:  942efeff.Patient.json
# remaining files:  35
# valid file:  94bef038.Patient.json
# remaining files:  34
# valid file:  95c5ea59.Patient.json
# remaining files:  33
# valid file:  a1f91f29.Patient.json
# remaining files:  32
# valid file:  a4dd2b51.Patient.json
# remaining files:  31
# valid file:  a5b44363.Patient.json
# remaining files:  30
# valid file:  a8ab1fd7.Patient.json
# remaining files:  29
# valid file:  aa26c53c.Patient.json
# remaining files:  28
# valid file:  abfc1218.Patient.json
# remaining files:  27
# valid file:  afe0d1e7.Patient.json
# remaining files:  26
# valid file:  b0893bc9.Patient.json
# remaining files:  25
# valid file:  b10426c7.Patient.json
# remaining files:  24
# valid file:  b61d14b2.Patient.json
# remaining files:  23
# valid file:  b6359037.Patient.json
# remaining files:  22
# valid file:  bebd51c0.Patient.json
# remaining files:  21
# valid file:  ca82304b.Patient.json
# remaining files:  20
# valid file:  d208de05.Patient.json
# remaining files:  19
# valid file:  d5493f31.Patient.json
# remaining files:  18
# valid file:  d87fb754.Patient.json
# remaining files:  17
# valid file:  ddf5ae5c.Patient.json
# remaining files:  16
# valid file:  de4594b3.Patient.json
# remaining files:  15
# valid file:  e18b08c5.Patient.json
# remaining files:  14
# valid file:  e45e7cd3.Patient.json
# remaining files:  13
# valid file:  e48062ab.Patient.json
# remaining files:  12
# valid file:  e8091ec6.Patient.json
# remaining files:  11
# valid file:  e83f6768.Patient.json
# remaining files:  10
# valid file:  ed1b9b07.Patient.json
# remaining files:  9
# valid file:  ed55dc2e.Patient.json
# remaining files:  8
# valid file:  eeb51cea.Patient.json
# remaining files:  7
# valid file:  f03e6289.Patient.json
# remaining files:  6
# valid file:  f048f16c.Patient.json
# remaining files:  5
# valid file:  f0bbcbe2.Patient.json
# remaining files:  4
# valid file:  f1a0053b.Patient.json
# remaining files:  3
# valid file:  f642778a.Patient.json
# remaining files:  2
# valid file:  fc20a24f.Patient.json
# remaining files:  1
# valid file:  feb74d8e.Patient.json
# READJOSN:---
# 00525954-8023-4658-acd3-6fd55568e80a
# remaining files:  100
# inserting:   00525954-8023-4658-acd3-6fd55568e80a
# READJOSN:---
# 019fe101-2d2b-4346-89d6-7c7187c0ee3c
# remaining files:  99
# inserting:   019fe101-2d2b-4346-89d6-7c7187c0ee3c
# READJOSN:---
# 039933a0-f970-4a84-bdab-fcbd85edd343
# remaining files:  98
# inserting:   039933a0-f970-4a84-bdab-fcbd85edd343
# READJOSN:---
# 03c2e1b5-9fe0-4735-bc7d-a54c449bfdae
# remaining files:  97
# inserting:   03c2e1b5-9fe0-4735-bc7d-a54c449bfdae
# READJOSN:---
# 0debf275-d585-4897-a8eb-25726def1ed5
# remaining files:  96
# inserting:   0debf275-d585-4897-a8eb-25726def1ed5
# READJOSN:---
# 0ee8938d-bf98-47d7-b1b2-3d4d072cb086
# remaining files:  95
# inserting:   0ee8938d-bf98-47d7-b1b2-3d4d072cb086
# READJOSN:---
# 0fbd8ed9-f4c0-442d-9cfb-98879a8be0eb
# remaining files:  94
# inserting:   0fbd8ed9-f4c0-442d-9cfb-98879a8be0eb
# READJOSN:---
# 103f95eb-1f89-4c43-9355-4293334153c1
# remaining files:  93
# inserting:   103f95eb-1f89-4c43-9355-4293334153c1
# READJOSN:---
# 13d0b13d-6dc2-4488-8311-eed260397ab7
# remaining files:  92
# inserting:   13d0b13d-6dc2-4488-8311-eed260397ab7
# READJOSN:---
# 13f9b410-5436-45bc-a6d3-b4dff5391295
# remaining files:  91
# inserting:   13f9b410-5436-45bc-a6d3-b4dff5391295
# READJOSN:---
# 150ec7a2-5ffd-497d-b0a7-4ce27de2ef7e
# remaining files:  90
# inserting:   150ec7a2-5ffd-497d-b0a7-4ce27de2ef7e
# READJOSN:---
# 163950fe-3224-4607-80e7-0ff35ab44b21
# remaining files:  89
# inserting:   163950fe-3224-4607-80e7-0ff35ab44b21
# READJOSN:---
# 1a0b9aff-aac4-4a6c-bd2b-07d963a8da1e
# remaining files:  88
# inserting:   1a0b9aff-aac4-4a6c-bd2b-07d963a8da1e
# READJOSN:---
# 1c18689e-63db-4317-94ea-974f2c7d122c
# remaining files:  87
# inserting:   1c18689e-63db-4317-94ea-974f2c7d122c
# READJOSN:---
# 21e57853-a27a-467d-ae70-bef5fbe5219c
# remaining files:  86
# inserting:   21e57853-a27a-467d-ae70-bef5fbe5219c
# READJOSN:---
# 2295fbd8-8572-4490-a607-61fb6c7e87e0
# remaining files:  85
# inserting:   2295fbd8-8572-4490-a607-61fb6c7e87e0
# READJOSN:---
# 2805041e-2730-49df-b779-0278afa476fb
# remaining files:  84
# inserting:   2805041e-2730-49df-b779-0278afa476fb
# READJOSN:---
# 2a868ded-2bec-446f-8fe9-8a1a91b1f268
# remaining files:  83
# inserting:   2a868ded-2bec-446f-8fe9-8a1a91b1f268
# READJOSN:---
# 2dc078cd-2239-4d61-92f0-817bce581413
# remaining files:  82
# inserting:   2dc078cd-2239-4d61-92f0-817bce581413
# READJOSN:---
# 2f5a5107-0fca-4b56-87bd-e25aeeb0860b
# remaining files:  81
# inserting:   2f5a5107-0fca-4b56-87bd-e25aeeb0860b
# READJOSN:---
# 30803573-9183-4187-84fe-58643a789c6e
# remaining files:  80
# inserting:   30803573-9183-4187-84fe-58643a789c6e
# READJOSN:---
# 3b7ebb7e-6b75-43dc-b359-e8b76ff9da54
# remaining files:  79
# inserting:   3b7ebb7e-6b75-43dc-b359-e8b76ff9da54
# READJOSN:---
# 3c9a0fe6-156a-4190-ae6b-ebb6f07e52cf
# remaining files:  78
# inserting:   3c9a0fe6-156a-4190-ae6b-ebb6f07e52cf
# READJOSN:---
# 3c9ff6d5-a74c-442b-a3b4-9ee76de365ae
# remaining files:  77
# inserting:   3c9ff6d5-a74c-442b-a3b4-9ee76de365ae
# READJOSN:---
# 3f363411-0930-4c07-87c2-475e3fc028b7
# remaining files:  76
# inserting:   3f363411-0930-4c07-87c2-475e3fc028b7
# READJOSN:---
# 3f403543-30b4-40f8-b8b6-e34d6bba82b9
# remaining files:  75
# inserting:   3f403543-30b4-40f8-b8b6-e34d6bba82b9
# READJOSN:---
# 3f6ca148-1800-44bd-9274-4196f8e6e77d
# remaining files:  74
# inserting:   3f6ca148-1800-44bd-9274-4196f8e6e77d
# READJOSN:---
# 43fc2d9d-4615-449d-a8d7-ea1f72a18d40
# remaining files:  73
# inserting:   43fc2d9d-4615-449d-a8d7-ea1f72a18d40
# READJOSN:---
# 4506837b-1602-46b2-9a7f-421f18ef871e
# remaining files:  72
# inserting:   4506837b-1602-46b2-9a7f-421f18ef871e
# READJOSN:---
# 4b8f21f6-edfb-4996-8e95-ea5defb34460
# remaining files:  71
# inserting:   4b8f21f6-edfb-4996-8e95-ea5defb34460
# READJOSN:---
# 4c22cd07-c065-4d66-bb9c-bde24376951d
# remaining files:  70
# inserting:   4c22cd07-c065-4d66-bb9c-bde24376951d
# READJOSN:---
# 4e13f416-7aa7-48c1-bd0b-d11094368bae
# remaining files:  69
# inserting:   4e13f416-7aa7-48c1-bd0b-d11094368bae
# READJOSN:---
# 5077322e-a154-46af-b735-488e14eacc7e
# remaining files:  68
# inserting:   5077322e-a154-46af-b735-488e14eacc7e
# READJOSN:---
# 517c31b6-7969-47e4-ad1d-42afa51d3473
# remaining files:  67
# inserting:   517c31b6-7969-47e4-ad1d-42afa51d3473
# READJOSN:---
# 54296ed1-cce8-4074-bf41-7038a0914020
# remaining files:  66
# inserting:   54296ed1-cce8-4074-bf41-7038a0914020
# READJOSN:---
# 56f18382-87e9-423b-8908-2a83cdddf9b3
# remaining files:  65
# inserting:   56f18382-87e9-423b-8908-2a83cdddf9b3
# READJOSN:---
# 59667014-7880-427b-8246-9ac805f4cb22
# remaining files:  64
# inserting:   59667014-7880-427b-8246-9ac805f4cb22
# READJOSN:---
# 5cf627cb-fbf1-4106-b292-a624a1c3f9a1
# remaining files:  63
# inserting:   5cf627cb-fbf1-4106-b292-a624a1c3f9a1
# READJOSN:---
# 60e8789a-9b3b-4955-a83a-680d6ab35545
# remaining files:  62
# inserting:   60e8789a-9b3b-4955-a83a-680d6ab35545
# READJOSN:---
# 61c0f781-e58c-451d-a1c0-64ae0d050aff
# remaining files:  61
# inserting:   61c0f781-e58c-451d-a1c0-64ae0d050aff
# READJOSN:---
# 63db01d9-caf0-4707-a89e-a8816e8c76de
# remaining files:  60
# inserting:   63db01d9-caf0-4707-a89e-a8816e8c76de
# READJOSN:---
# 653711aa-c143-4e6f-bf5c-ade2580dc340
# remaining files:  59
# inserting:   653711aa-c143-4e6f-bf5c-ade2580dc340
# READJOSN:---
# 67cbee98-46f9-4aaf-b912-2ebefb903753
# remaining files:  58
# inserting:   67cbee98-46f9-4aaf-b912-2ebefb903753
# READJOSN:---
# 688c0771-a1f9-4879-8dd0-83842163740f
# remaining files:  57
# inserting:   688c0771-a1f9-4879-8dd0-83842163740f
# READJOSN:---
# 6a370e45-d49f-47da-8add-f397106a7035
# remaining files:  56
# inserting:   6a370e45-d49f-47da-8add-f397106a7035
# READJOSN:---
# 6d615362-bcbd-4b31-9240-ad3b0c19f0b1
# remaining files:  55
# inserting:   6d615362-bcbd-4b31-9240-ad3b0c19f0b1
# READJOSN:---
# 6f8f470e-07e8-4273-ad11-6e3fdc384a09
# remaining files:  54
# inserting:   6f8f470e-07e8-4273-ad11-6e3fdc384a09
# READJOSN:---
# 70fcb282-0564-470e-9057-e23fee5642a9
# remaining files:  53
# inserting:   70fcb282-0564-470e-9057-e23fee5642a9
# READJOSN:---
# 7288e90e-0e77-47aa-97bb-c87664ad037e
# remaining files:  52
# inserting:   7288e90e-0e77-47aa-97bb-c87664ad037e
# READJOSN:---
# 770596b9-3c34-4311-a289-43cb5e308a14
# remaining files:  51
# inserting:   770596b9-3c34-4311-a289-43cb5e308a14
# READJOSN:---
# 79a1687e-3e6f-4ec0-82da-67c6aba4edb1
# remaining files:  50
# inserting:   79a1687e-3e6f-4ec0-82da-67c6aba4edb1
# READJOSN:---
# 83b3beed-10e0-4fb0-b0c6-64b1a7745d05
# remaining files:  49
# inserting:   83b3beed-10e0-4fb0-b0c6-64b1a7745d05
# READJOSN:---
# 862e0d5a-98e3-400d-9a2c-d74aaa505845
# remaining files:  48
# inserting:   862e0d5a-98e3-400d-9a2c-d74aaa505845
# READJOSN:---
# 887b7be5-86a0-4ed7-b449-f9b14a3e04c3
# remaining files:  47
# inserting:   887b7be5-86a0-4ed7-b449-f9b14a3e04c3
# READJOSN:---
# 888c2d5f-33b5-4959-acfe-cc65abc50f3c
# remaining files:  46
# inserting:   888c2d5f-33b5-4959-acfe-cc65abc50f3c
# READJOSN:---
# 88a3d349-f6f3-4d3a-94ef-6fbdbbe326a4
# remaining files:  45
# inserting:   88a3d349-f6f3-4d3a-94ef-6fbdbbe326a4
# READJOSN:---
# 8934b7cf-daa9-47b1-8b33-7d6f85dce97d
# remaining files:  44
# inserting:   8934b7cf-daa9-47b1-8b33-7d6f85dce97d
# READJOSN:---
# 895cd302-bee7-4933-a8f1-674344a87035
# remaining files:  43
# inserting:   895cd302-bee7-4933-a8f1-674344a87035
# READJOSN:---
# 8a34821b-e184-4fbd-80c1-2d4d430b3523
# remaining files:  42
# inserting:   8a34821b-e184-4fbd-80c1-2d4d430b3523
# READJOSN:---
# 8a9356db-3e1f-480b-913f-996c055cf21f
# remaining files:  41
# inserting:   8a9356db-3e1f-480b-913f-996c055cf21f
# READJOSN:---
# 8ada3b39-0359-4209-9b30-5fb430ad4355
# remaining files:  40
# inserting:   8ada3b39-0359-4209-9b30-5fb430ad4355
# READJOSN:---
# 8dbb72ab-5fae-4cda-bb84-1f586bea22d5
# remaining files:  39
# inserting:   8dbb72ab-5fae-4cda-bb84-1f586bea22d5
# READJOSN:---
# 93f70310-ca43-49cf-8aa1-85cb668ded15
# remaining files:  38
# inserting:   93f70310-ca43-49cf-8aa1-85cb668ded15
# READJOSN:---
# 93fa40da-589d-437a-863f-7928176725ba
# remaining files:  37
# inserting:   93fa40da-589d-437a-863f-7928176725ba
# READJOSN:---
# 942efeff-48f3-4dc6-a9f1-6f7ab0fa88b5
# remaining files:  36
# inserting:   942efeff-48f3-4dc6-a9f1-6f7ab0fa88b5
# READJOSN:---
# 94bef038-b168-47ec-bb0e-0184ae8fd604
# remaining files:  35
# inserting:   94bef038-b168-47ec-bb0e-0184ae8fd604
# READJOSN:---
# 95c5ea59-ec2b-4970-9259-e449a4cf4599
# remaining files:  34
# inserting:   95c5ea59-ec2b-4970-9259-e449a4cf4599
# READJOSN:---
# a1f91f29-b0d7-4f4c-a530-b7719dfbd470
# remaining files:  33
# inserting:   a1f91f29-b0d7-4f4c-a530-b7719dfbd470
# READJOSN:---
# a4dd2b51-a129-471f-b072-30bd098ed3c7
# remaining files:  32
# inserting:   a4dd2b51-a129-471f-b072-30bd098ed3c7
# READJOSN:---
# a5b44363-36a3-4848-a617-3dd45ffde5f3
# remaining files:  31
# inserting:   a5b44363-36a3-4848-a617-3dd45ffde5f3
# READJOSN:---
# a8ab1fd7-9c21-4902-94e5-486b690b5797
# remaining files:  30
# inserting:   a8ab1fd7-9c21-4902-94e5-486b690b5797
# READJOSN:---
# aa26c53c-925e-4bc9-ad13-3150b04d36cc
# remaining files:  29
# inserting:   aa26c53c-925e-4bc9-ad13-3150b04d36cc
# READJOSN:---
# abfc1218-dc59-404d-85d4-1f9b6b844ce7
# remaining files:  28
# inserting:   abfc1218-dc59-404d-85d4-1f9b6b844ce7
# READJOSN:---
# afe0d1e7-5c2e-4b3f-9494-c4011a9e8641
# remaining files:  27
# inserting:   afe0d1e7-5c2e-4b3f-9494-c4011a9e8641
# READJOSN:---
# b0893bc9-89d3-42db-b3a4-331b939715cc
# remaining files:  26
# inserting:   b0893bc9-89d3-42db-b3a4-331b939715cc
# READJOSN:---
# b10426c7-f0df-46fd-95f6-b2d3d2cde59c
# remaining files:  25
# inserting:   b10426c7-f0df-46fd-95f6-b2d3d2cde59c
# READJOSN:---
# b61d14b2-945c-4d22-8d65-9d5b73e96fb9
# remaining files:  24
# inserting:   b61d14b2-945c-4d22-8d65-9d5b73e96fb9
# READJOSN:---
# b6359037-63f4-4775-ace4-8f69c774ffa7
# remaining files:  23
# inserting:   b6359037-63f4-4775-ace4-8f69c774ffa7
# READJOSN:---
# bebd51c0-a15f-4363-8591-27d748f060a9
# remaining files:  22
# inserting:   bebd51c0-a15f-4363-8591-27d748f060a9
# READJOSN:---
# ca82304b-3e09-40c1-99a4-21624511e481
# remaining files:  21
# inserting:   ca82304b-3e09-40c1-99a4-21624511e481
# READJOSN:---
# d208de05-5f89-4ca7-a455-ee0687384fa0
# remaining files:  20
# inserting:   d208de05-5f89-4ca7-a455-ee0687384fa0
# READJOSN:---
# d5493f31-c843-4f0e-b2fa-1cca82029325
# remaining files:  19
# inserting:   d5493f31-c843-4f0e-b2fa-1cca82029325
# READJOSN:---
# d87fb754-f3e4-4ea4-9e08-3fc60f116104
# remaining files:  18
# inserting:   d87fb754-f3e4-4ea4-9e08-3fc60f116104
# READJOSN:---
# ddf5ae5c-5646-4a76-9efd-f7e697f3b728
# remaining files:  17
# inserting:   ddf5ae5c-5646-4a76-9efd-f7e697f3b728
# READJOSN:---
# de4594b3-48d0-4bd5-aac8-dbf07cefe8ea
# remaining files:  16
# inserting:   de4594b3-48d0-4bd5-aac8-dbf07cefe8ea
# READJOSN:---
# e18b08c5-f548-4f58-bb12-e5bf0ec9efb1
# remaining files:  15
# inserting:   e18b08c5-f548-4f58-bb12-e5bf0ec9efb1
# READJOSN:---
# e45e7cd3-b1ef-4813-b010-096c1e2c960f
# remaining files:  14
# inserting:   e45e7cd3-b1ef-4813-b010-096c1e2c960f
# READJOSN:---
# e48062ab-d270-4dc4-8812-f6be8a588238
# remaining files:  13
# inserting:   e48062ab-d270-4dc4-8812-f6be8a588238
# READJOSN:---
# e8091ec6-702e-4fc7-b46d-d6ad4c0874e1
# remaining files:  12
# inserting:   e8091ec6-702e-4fc7-b46d-d6ad4c0874e1
# READJOSN:---
# e83f6768-a9ca-470a-b538-953429f1f924
# remaining files:  11
# inserting:   e83f6768-a9ca-470a-b538-953429f1f924
# READJOSN:---
# ed1b9b07-be04-4d88-b00d-b8447ba1b7a7
# remaining files:  10
# inserting:   ed1b9b07-be04-4d88-b00d-b8447ba1b7a7
# READJOSN:---
# ed55dc2e-e921-4439-bf1f-e5f789ee0def
# remaining files:  9
# inserting:   ed55dc2e-e921-4439-bf1f-e5f789ee0def
# READJOSN:---
# eeb51cea-df7b-4dde-8a07-feb5c23db49a
# remaining files:  8
# inserting:   eeb51cea-df7b-4dde-8a07-feb5c23db49a
# READJOSN:---
# f03e6289-fef3-4262-887a-19541dd81205
# remaining files:  7
# inserting:   f03e6289-fef3-4262-887a-19541dd81205
# READJOSN:---
# f048f16c-6526-4574-98bd-dabd92752059
# remaining files:  6
# inserting:   f048f16c-6526-4574-98bd-dabd92752059
# READJOSN:---
# f0bbcbe2-4abc-4b13-9be1-9ae9a17db915
# remaining files:  5
# inserting:   f0bbcbe2-4abc-4b13-9be1-9ae9a17db915
# READJOSN:---
# f1a0053b-ef85-44cf-82e4-9745a481c463
# remaining files:  4
# inserting:   f1a0053b-ef85-44cf-82e4-9745a481c463
# READJOSN:---
# f642778a-a527-4c85-b6fa-3d37745d9957
# remaining files:  3
# inserting:   f642778a-a527-4c85-b6fa-3d37745d9957
# READJOSN:---
# fc20a24f-eee5-45b4-b8ab-c1f5a9818b47
# remaining files:  2
# inserting:   fc20a24f-eee5-45b4-b8ab-c1f5a9818b47
# READJOSN:---
# feb74d8e-63dc-40ce-af7a-add8cbd86fc1
# remaining files:  1
# inserting:   feb74d8e-63dc-40ce-af7a-add8cbd86fc1
